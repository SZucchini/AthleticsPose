# %% [markdown]
# # 3D Pose Estimation Demo
#
# このノートブックでは、動画から3D姿勢推定を行うデモを実行します。
#
# ## セットアップ
#
# まず、実行に必要な環境を構築します。

# %%
# !nvcc --version

# %%
# !python -V

# %%
# @title CUDA 11.8のインストールと有効化

# %cd /content

import os

# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64/cuda-ubuntu2004.pin
# !sudo mv cuda-ubuntu2004.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget https://developer.download.nvidia.com/compute/cuda/11.8.0/local_installers/cuda-repo-ubuntu2004-11-8-local_11.8.0-520.61.05-1_amd64.deb
# !sudo dpkg -i cuda-repo-ubuntu2004-11-8-local_11.8.0-520.61.05-1_amd64.deb
# !sudo cp /var/cuda-repo-ubuntu2004-11-8-local/cuda-*-keyring.gpg /usr/share/keyrings/
# !sudo apt-get update
# !sudo apt-get -y install cuda-11-8

# %env PATH=PATH:/usr/local/cuda-11.8/bin:{os.getenv('PATH')}
# %env BNB_CUDA_VERSION=118
# %env CUDA_VERSION=118
# %env LD_LIBRARY_PATH=/usr/local/cuda-11.8/lib64:{os.environ['LD_LIBRARY_PATH']}
# !nvcc --version

# %%
# @title リポジトリのクローンと必要なファイルのアップロード

# !git clone https://github.com/SZucchini/AthleticsPose.git
# !cd AthleticsPose && git checkout feat/gradio-demo

# 作成される以下のディレクトリにチェックポイントファイルをアップロードしてください。
# !mkdir -p /content/checkpoint/

# %%
# @title 仮想環境の構築

# !pip install uv
# !cd AthleticsPose/ && uv sync --all-groups

# %% [markdown]
# ## デモの実行
#
# 以下のセルを実行して、Running on public URLをクリックするとデモページが表示されます。
# 動画をアップロードすると、3D姿勢推定の結果がアニメーションとして表示されます。
#
# **注意事項：**
# - 動画は10秒以内のものを使用してください
# - 動画が長いほど処理に必要な時間がかかります
# - 推奨解像度はHD（1920x1080）です
# - 1人の人物が映っている動画を使用してください

# %%
# @title 実行

# !source /content/AthleticsPose/.venv/bin/activate  && cd AthleticsPose/ && python demo/app.py /content/checkpoint/best.ckpt

# %% [markdown]
# ## トラブルシューティング
#
# 問題が発生した場合は、以下を確認してください：
#
# 1. モデルチェックポイントが正しくコピーされているか
# 2. 入力動画が要件を満たしているか（長さ、解像度）
# 3. 1人の人物がはっきりと映っているか
#
# エラーが続く場合は、ランタイムを再起動して最初からやり直してみてください。
